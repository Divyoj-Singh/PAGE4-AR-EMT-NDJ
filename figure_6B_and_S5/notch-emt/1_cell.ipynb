# %%
import auxilary_functions as aux
from PyDSTool import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

DSargs          = args(name='Notch_EMT_1cell', checklevel=2)
DSargs.pars     = aux.parameters(onecell=True)
DSargs.varspecs = aux.equations(onecell=True)
DSargs.fnspecs  = aux.functions()
DSargs.ics      = {'W': 20000.0, 'Z': 40000.0,'Y': 20000.0,'S': 200000.0
                  ,'N':  0.0e+0, 'D': 0.0e+0, 'J': 0.0e+0, 'I': 20.0e+0
                  }
DSargs.xdomain  = {'W': [0, 5.0e+4],'Z': [0, 5.0e+6],'Y': [0, 5.0e+4],'S': [0, 5.0e+5]
                  ,'N': [0, 5.0e+5],'D': [0, 5.0e+5],'J': [0, 5.0e+5],'I': [0, 5.0e+5]
                  }
DSargs.pdomain  = {'Dt': [-0.1e+0, 1.0e+3],'Jt': [-0.1e+0, 1.1e+4],'It': [-0.1e+0, 3.0e+3]
                  }
DSargs.tdomain  = [0., 100.0]
DSargs.algparams= {'init_step':1.0e-1}
ODE = Vode_ODEsystem(DSargs)

# %%
ODE = Vode_ODEsystem(DSargs)
ODE.set(pars = {'Nt': 1.0e+4, 'gD': 40, 'gJ': 15})

freepar = 'Jt'
fp=aux.fast_fixedpoint(ODE)
# --------------------- Figure 3A -------------------------------------
aux.plot_continuation(ODE, freepar, keys=['W'], ncol=1, nrow=1, LocBifPoints=['LP','B'], bif_startpoint=100, 
                      maxstep=1e+4, minstep=1e-1, step=5e+2, silence=True, fs=[6,5], ics=[fp], xlim=[0, 10000])

freepar = 'Dt'
fp=aux.fast_fixedpoint(ODE)
# --------------------- Figure 3C -------------------------------------
aux.plot_continuation(ODE, freepar, keys=['W'], ncol=1, nrow=1, LocBifPoints=['LP','B'], bif_startpoint=10, 
                      maxstep=1e+4, minstep=1e-1, step=5e+2, silence=True, fs=[6,5], ics=[fp], xlim=[0, 1000])
# Out:
# C:\Users\divyo\anaconda3\envs\python27\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Using pyplot.axes(ax) with ax an Axes argument is deprecated. Please use pyplot.sca(ax) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
ODE = Vode_ODEsystem(DSargs)
ODE.set(pars = {'Nt': 1.0e+4, 'gD': 40, 'gJ': 15})
freepar = 'Dt'
fp=aux.fast_fixedpoint(ODE)
# --------------------- Figure 3C -------------------------------------
aux.plot_continuation(ODE, freepar, keys=['N'], ncol=1, nrow=1, LocBifPoints=['LP','B'], bif_startpoint=10, 
                      maxstep=1e+4, minstep=1e-1, step=5e+2, silence=True, fs=[6,5], ics=[fp], xlim=[0, 1000])
freepar = 'Dt'
fp=aux.fast_fixedpoint(ODE)
# --------------------- Figure 3C -------------------------------------
aux.plot_continuation(ODE, freepar, keys=['D'], ncol=1, nrow=1, LocBifPoints=['LP','B'], bif_startpoint=10, 
                      maxstep=1e+4, minstep=1e-1, step=5e+2, silence=True, fs=[6,5], ics=[fp], xlim=[0, 1000])
freepar = 'Dt'
fp=aux.fast_fixedpoint(ODE)
# --------------------- Figure 3C -------------------------------------
aux.plot_continuation(ODE, freepar, keys=['J'], ncol=1, nrow=1, LocBifPoints=['LP','B'], bif_startpoint=10, 
                      maxstep=1e+4, minstep=1e-1, step=5e+2, silence=True, fs=[6,5], ics=[fp], xlim=[0, 1000])
